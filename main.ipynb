# %% [markdown]
# ## Importar librerias

# %%
from simpy import Environment, Container, Resource
import random
import pandas as pd

# %% [markdown]
# ## Variables de configuracion

# %%
NUM_VEHICULOS = 5
NUM_ASIENTOS_VEHICULO = 4
DURACION_SIMULACION = 180
# Nombre de la colonia y distancia (km) relativa al punto de taxi
COLONIAS_SETTINGS = [
    { "nombre": "A", "distancia": 1 }
    , { "nombre": "B", "distancia": 3 }
    , { "nombre": "C", "distancia": 2 }
]

# %% [markdown]
# ## Definicion de clases

# %% [markdown]
# ### Clases para representar destino de los pasajeros

# %%
class Colonia:
    def __init__(self, nombre: str, distancia_absoluta: int):
        self.nombre = nombre
        self.distancia_absoluta = distancia_absoluta
        
class Destino:
    def __init__(self, colonia: Colonia, punto: int):
        self.colonia = colonia
        self.punto = punto
        self.distancia_absoluta = self.colonia.distancia_absoluta * (self.punto / 5)

# %% [markdown]
# ### Clase para representar el punto de taxi

# %%
class PuntoTaxi:
    def __init__(self, env: Environment, colonias: [Colonia], vehiculos):
        self.env = env
        self.vehiculos = Resource(
            env
            , capacity = NUM_VEHICULOS
        )
        # Hay una fila de pasajeros por colonia
        self.colas_pasajeros: dict = { c.nombre: [] for c in colonias }
        self.cola_vehiculos = vehiculos

# %% [markdown]
# ### Clase para representar pasajeros

# %%
class Pasajero:
    def __init__(self, env: Environment, id: int, destino: Destino, punto_taxi: PuntoTaxi):
        self.env = env
        self.id = id
        self.destino = destino
        self.punto_taxi = punto_taxi
        self.env.process(self.start())
        self.vehiculo: int = None
        self.eventos = pd.DataFrame()

    def start(self):
        print(f"{self.env.now}: pasajero con id {self.id} llego al punto con destino: colonia {self.destino.colonia.nombre}, punto {self.destino.punto}")

        self.eventos = pd.concat([
            self.eventos
            , pd.DataFrame({
                "pasajero": [self.id]
                , "evento": ["LLEGO AL PUNTO"]
                , "tiempo": [self.env.now]
            })
        ])

        with self.punto_taxi.vehiculos.request() as req:
            colonia = self.destino.colonia.nombre
            cola_pasajeros = self.punto_taxi.colas_pasajeros[colonia]
            
            # Deben haber minimo 4 pasajeros con el mismo destino para realizar el viaje
            if len(cola_pasajeros) < NUM_ASIENTOS_VEHICULO:
                return
            
            # Obtener primeros 4 pasajeros por orden de llegada
            # Ordenar de forma ascendente en funcion de la distancia absoluta de su destino
            siguientes_pasajeros = sorted([ cola_pasajeros.pop(0) for _ in range(NUM_ASIENTOS_VEHICULO) ], key = lambda p: p.destino.punto)
            # siguientes_pasajeros = [ cola_pasajeros.pop(0) for _ in range(NUM_ASIENTOS_VEHICULO) ]
            ids_pasajeros = [ p.id for p in siguientes_pasajeros ]
            
            print(f"{self.env.now}: pasajeros {ids_pasajeros} con destino a colonia {colonia} listos para subir a taxi")
            
            yield req

            # Obtener el primer taxi de la cola
            vehiculo: Vehiculo = self.punto_taxi.cola_vehiculos.pop(0)

            for pasajero in siguientes_pasajeros:
                pasajero.eventos = pd.concat([
                    pasajero.eventos
                    , pd.DataFrame({
                        "pasajero": [pasajero.id]
                        , "evento": ["SUBIO A VEHICULO"]
                        , "tiempo": [self.env.now]
                    })
                ])

                pasajero.vehiculo = vehiculo.id

            vehiculo.eventos = pd.concat([
                vehiculo.eventos
                , pd.DataFrame({
                    "vehiculo": [vehiculo.id]
                    , "evento": ["HACIA EL DESTINO"]
                    , "tiempo": [self.env.now]
                })
            ])

            print(f"{self.env.now}: pasajeros {ids_pasajeros} subieron a vehiculo con id {vehiculo.id}")

            # self.env.process(vehiculo.start(siguientes_pasajeros))
            
            velocidad_const = random.randint(15, 25)
            
            t_abs = [ int(60 * p.destino.distancia_absoluta / velocidad_const) for p in siguientes_pasajeros ]
            t_relat = [t_abs[0]] + [ t_abs[i] - t_abs[i - 1] for i in range(1, len(t_abs)) ]

            now = self.env.now

            # Pasajeros estan dentro del vehiculo
            for pasajero, tiempo in zip(siguientes_pasajeros, t_relat):
                yield self.env.timeout(tiempo)

                pasajero.eventos = pd.concat([
                    pasajero.eventos
                    , pd.DataFrame({
                        "pasajero": [pasajero.id]
                        , "evento": ["LLEGO A SU DESTINO"]
                        , "tiempo": [self.env.now]
                    })
                ])

                print(f"{self.env.now}: pasajero con id {pasajero.id} llego a su destino: colonia {colonia}, punto {pasajero.destino.punto}")

            print(f"{self.env.now}: vehiculo con id {vehiculo.id} volviendo al punto de taxi...")

            vehiculo.eventos = pd.concat([
                vehiculo.eventos
                , pd.DataFrame({
                    "vehiculo": [vehiculo.id]
                    , "evento": ["HACIA EL PUNTO"]
                    , "tiempo": [self.env.now]
                })
            ])
                
            yield self.env.timeout(max(t_abs))

            vehiculo.eventos = pd.concat([
                vehiculo.eventos
                , pd.DataFrame({
                    "vehiculo": [vehiculo.id]
                    , "evento": ["LLEGO AL PUNTO"]
                    , "tiempo": [self.env.now]
                })
            ])
            
            print(f"{self.env.now}: vehiculo con id {vehiculo.id} volvio al punto de taxi. Tiempo del viaje: {self.env.now - now}")

            self.punto_taxi.cola_vehiculos.append(vehiculo)

# %% [markdown]
# ### Clase para representar vehiculos (taxis)

# %%
class Vehiculo:
    def __init__(self, env: Environment, id: int):
        self.env = env
        self.id = id
        self.asientos = Container(
            env
            , init = NUM_ASIENTOS_VEHICULO
            , capacity = NUM_ASIENTOS_VEHICULO
        )
        self.eventos = pd.DataFrame({
            "vehiculo": [self.id]
            , "evento": ["LLEGO AL PUNTO"]
            , "tiempo": [0]
        })

    def start(self, pasajeros: [Pasajero]):
        pass

# %% [markdown]
# ### Clase para la simulacion

# %%
class Simulacion:
    def __init__(self, env: Environment):
        self.env = env
        self.colonias: [Colonia] = [ Colonia(s["nombre"], s["distancia"]) for s in COLONIAS_SETTINGS ]
        self.pasajeros = []
        self.vehiculos = [ Vehiculo(env, i) for i in range(NUM_VEHICULOS) ]
        self.punto_taxi = PuntoTaxi(env, self.colonias, self.vehiculos.copy())
        self.env.process(self.start())

    def start(self):
        while True:
            # Pasajero(s) llegan cada 1-5 minutos
            yield self.env.timeout(random.randint(1, 5))

            for _ in range(random.randint(1, 3)):
                colonia: Colonia = random.choice(self.colonias)                
                destino = Destino(colonia, random.randint(1, 10))
                
                pasajero = Pasajero(
                    self.env
                    , len(self.pasajeros) + 1
                    , destino
                    , self.punto_taxi
                )

                self.pasajeros.append(pasajero)
                self.punto_taxi.colas_pasajeros[colonia.nombre].append(pasajero)

# %% [markdown]
# ## Iniciar simulacion

# %%
random.seed(333)

env = Environment()

simulacion = Simulacion(env)

env.run( until = DURACION_SIMULACION )
# Out:
# 5: pasajero con id 1 llego al punto con destino: colonia B, punto 4
# 5: pasajero con id 2 llego al punto con destino: colonia B, punto 2
# 8: pasajero con id 3 llego al punto con destino: colonia C, punto 6
# 8: pasajero con id 4 llego al punto con destino: colonia B, punto 5
# 8: pasajero con id 5 llego al punto con destino: colonia A, punto 6
# 13: pasajero con id 6 llego al punto con destino: colonia B, punto 2
# 13: pasajeros [2, 6, 1, 4] con destino a colonia B listos para subir a taxi
# 13: pasajeros [2, 6, 1, 4] subieron a vehiculo con id 0
# 16: pasajero con id 7 llego al punto con destino: colonia B, punto 8
# 16: pasajero con id 8 llego al punto con destino: colonia C, punto 5
# 17: pasajero con id 2 llego a su destino: colonia B, punto 2
# 17: pasajero con id 6 llego a su destino: colonia B, punto 2
# 20: pasajero con id 9 llego al punto con destino: colonia B, punto 9
# 22: pasajero con id 1 llego a su destino: colonia B, punto 4
# 23: pasajero con id 10 llego al punto con destino: colonia B, punto 3
# 25: pasajero con id 4 llego a su destino: colonia B, punto 5
# 25: vehiculo con id 0 volviendo al punto de taxi...
# 27: pasajero con id 11 llego al punto con destino: colonia C, punto 2
# 29: pasajero con id 12 llego al punto con destino: colonia A, punto 5
# 31: pasajero con id 13 llego al punto con destino: colonia B, punto 3
# 31: pasajeros [10, 13, 7, 9] con destino a colonia B listos para subir a taxi
# 31: pasajero con id 14 llego al punto con destino: colonia B, punto 1
# 31: pasajero con id 15 llego al punto con destino: colonia A, punto 4
# 31: pasajeros [10, 13, 7, 9] subieron a vehiculo con id 1
# 35: pasajero con id 16 llego al punto con destino: colonia B, punto 6
# 35: pasajeros [14, 17, 16, 18] con destino a colonia B listos para subir a taxi
# 35: pasajero con id 17 llego al punto con destino: colonia B, punto 2
# 35: pasajero con id 18 llego al punto con destino: colonia B, punto 6
# 35: pasajeros [14, 17, 16, 18] subieron a vehiculo con id 2
# 36: pasajero con id 10 llego a su destino: colonia B, punto 3
# 36: pasajero con id 14 llego a su destino: colonia B, punto 1
# 36: pasajero con id 13 llego a su destino: colonia B, punto 3
# 37: vehiculo con id 0 volvio al punto de taxi. Tiempo del viaje: 24
# 38: pasajero con id 17 llego a su destino: colonia B, punto 2
# 40: pasajero con id 19 llego al punto con destino: colonia B, punto 2
# 40: pasajero con id 20 llego al punto con destino: colonia A, punto 1
# 40: pasajeros [20, 15, 12, 5] con destino a colonia A listos para subir a taxi
# 40: pasajero con id 21 llego al punto con destino: colonia A, punto 3
# 40: pasajeros [20, 15, 12, 5] subieron a vehiculo con id 3
# 40: pasajero con id 20 llego a su destino: colonia A, punto 1
# 42: pasajero con id 15 llego a su destino: colonia A, punto 4
# 43: pasajero con id 22 llego al punto con destino: colonia B, punto 9
# 43: pasajero con id 23 llego al punto con destino: colonia A, punto 3
# 43: pasajero con id 24 llego al punto con destino: colonia C, punto 1
# 43: pasajeros [24, 11, 8, 3] con destino a colonia C listos para subir a taxi
# 43: pasajero con id 12 llego a su destino: colonia A, punto 5
# 43: pasajeros [24, 11, 8, 3] subieron a vehiculo con id 4
# 43: pasajero con id 5 llego a su destino: colonia A, punto 6
# 43: vehiculo con id 3 volviendo al punto de taxi...
# 44: pasajero con id 16 llego a su destino: colonia B, punto 6
# 44: pasajero con id 24 llego a su destino: colonia C, punto 1
# 44: pasajero con id 18 llego a su destino: colonia B, punto 6
# 44: vehiculo con id 2 volviendo al punto de taxi...
# 45: pasajero con id 7 llego a su destino: colonia B, punto 8
# 45: pasajero con id 11 llego a su destino: colonia C, punto 2
# 46: vehiculo con id 3 volvio al punto de taxi. Tiempo del viaje: 6
# 47: pasajero con id 9 llego a su destino: colonia B, punto 9
# 47: vehiculo con id 1 volviendo al punto de taxi...
# 48: pasajero con id 25 llego al punto con destino: colonia A, punto 7
# 48: pasajeros [21, 23, 25, 26] con destino a colonia A listos para subir a taxi
# 48: pasajero con id 26 llego al punto con destino: colonia A, punto 10
# 48: pasajero con id 27 llego al punto con destino: colonia B, punto 10
# 48: pasajeros [21, 23, 25, 26] subieron a vehiculo con id 0
# 49: pasajero con id 8 llego a su destino: colonia C, punto 5
# 49: pasajero con id 21 llego a su destino: colonia A, punto 3
# 49: pasajero con id 23 llego a su destino: colonia A, punto 3
# 50: pasajero con id 3 llego a su destino: colonia C, punto 6
# 50: vehiculo con id 4 volviendo al punto de taxi...
# 52: pasajero con id 25 llego a su destino: colonia A, punto 7
# 53: vehiculo con id 2 volvio al punto de taxi. Tiempo del viaje: 18
# 53: pasajero con id 28 llego al punto con destino: colonia B, punto 4
# 53: pasajeros [19, 28, 22, 27] con destino a colonia B listos para subir a taxi
# 53: pasajero con id 29 llego al punto con destino: colonia A, punto 4
# 53: pasajeros [19, 28, 22, 27] subieron a vehiculo con id 3
# 54: pasajero con id 26 llego a su destino: colonia A, punto 10
# 54: vehiculo con id 0 volviendo al punto de taxi...
# 55: pasajero con id 30 llego al punto con destino: colonia B, punto 5
# 55: pasajero con id 31 llego al punto con destino: colonia B, punto 5
# 56: pasajero con id 19 llego a su destino: colonia B, punto 2
# 57: vehiculo con id 4 volvio al punto de taxi. Tiempo del viaje: 14
# 57: pasajero con id 32 llego al punto con destino: colonia A, punto 6
# 57: pasajero con id 33 llego al punto con destino: colonia A, punto 1
# 57: pasajero con id 34 llego al punto con destino: colonia B, punto 3
# 59: pasajero con id 28 llego a su destino: colonia B, punto 4
# 60: vehiculo con id 0 volvio al punto de taxi. Tiempo del viaje: 12
# 62: pasajero con id 35 llego al punto con destino: colonia C, punto 9
# 62: pasajero con id 36 llego al punto con destino: colonia B, punto 1
# 62: pasajeros [36, 34, 30, 31] con destino a colonia B listos para subir a taxi
# 62: pasajero con id 37 llego al punto con destino: colonia A, punto 5
# 62: pasajeros [33, 29, 37, 32] con destino a colonia A listos para subir a taxi
# 62: pasajeros [36, 34, 30, 31] subieron a vehiculo con id 2
# 62: pasajeros [33, 29, 37, 32] subieron a vehiculo con id 4
# 62: pasajero con id 33 llego a su destino: colonia A, punto 1
# 63: vehiculo con id 1 volvio al punto de taxi. Tiempo del viaje: 32
# 63: pasajero con id 36 llego a su destino: colonia B, punto 1
# 64: pasajero con id 29 llego a su destino: colonia A, punto 4
# 64: pasajero con id 37 llego a su destino: colonia A, punto 5
# 65: pasajero con id 38 llego al punto con destino: colonia B, punto 3
# 65: pasajero con id 39 llego al punto con destino: colonia A, punto 4
# 65: pasajero con id 32 llego a su destino: colonia A, punto 6
# 65: vehiculo con id 4 volviendo al punto de taxi...
# 66: pasajero con id 34 llego a su destino: colonia B, punto 3
# 67: pasajero con id 22 llego a su destino: colonia B, punto 9
# 68: pasajero con id 40 llego al punto con destino: colonia C, punto 9
# 68: pasajero con id 41 llego al punto con destino: colonia B, punto 6
# 68: vehiculo con id 4 volvio al punto de taxi. Tiempo del viaje: 6
# 68: pasajero con id 27 llego a su destino: colonia B, punto 10
# 68: vehiculo con id 3 volviendo al punto de taxi...
# 69: pasajero con id 42 llego al punto con destino: colonia A, punto 6
# 70: pasajero con id 30 llego a su destino: colonia B, punto 5
# 70: pasajero con id 31 llego a su destino: colonia B, punto 5
# 70: vehiculo con id 2 volviendo al punto de taxi...
# 71: pasajero con id 43 llego al punto con destino: colonia C, punto 10
# 71: pasajero con id 44 llego al punto con destino: colonia A, punto 7
# 73: pasajero con id 45 llego al punto con destino: colonia B, punto 6
# 75: pasajero con id 46 llego al punto con destino: colonia B, punto 8
# 75: pasajeros [38, 41, 45, 46] con destino a colonia B listos para subir a taxi
# 75: pasajero con id 47 llego al punto con destino: colonia C, punto 8
# 75: pasajeros [47, 35, 40, 43] con destino a colonia C listos para subir a taxi
# 75: pasajero con id 48 llego al punto con destino: colonia B, punto 10
# 75: pasajeros [38, 41, 45, 46] subieron a vehiculo con id 0
# 75: pasajeros [47, 35, 40, 43] subieron a vehiculo con id 1
# 78: vehiculo con id 2 volvio al punto de taxi. Tiempo del viaje: 16
# 79: pasajero con id 49 llego al punto con destino: colonia A, punto 5
# 79: pasajeros [39, 49, 42, 44] con destino a colonia A listos para subir a taxi
# 79: pasajero con id 50 llego al punto con destino: colonia B, punto 3
# 79: pasajero con id 51 llego al punto con destino: colonia A, punto 9
# 79: pasajeros [39, 49, 42, 44] subieron a vehiculo con id 4
# 81: pasajero con id 38 llego a su destino: colonia B, punto 3
# 81: pasajero con id 39 llego a su destino: colonia A, punto 4
# 82: pasajero con id 49 llego a su destino: colonia A, punto 5
# 83: vehiculo con id 3 volvio al punto de taxi. Tiempo del viaje: 30
# 83: pasajero con id 52 llego al punto con destino: colonia B, punto 10
# 83: pasajeros [50, 48, 52, 53] con destino a colonia B listos para subir a taxi
# 83: pasajero con id 53 llego al punto con destino: colonia B, punto 10
# 83: pasajero con id 42 llego a su destino: colonia A, punto 6
# 83: pasajeros [50, 48, 52, 53] subieron a vehiculo con id 2
# 83: pasajero con id 44 llego a su destino: colonia A, punto 7
# 83: vehiculo con id 4 volviendo al punto de taxi...
# 84: pasajero con id 54 llego al punto con destino: colonia A, punto 3
# 84: pasajero con id 55 llego al punto con destino: colonia C, punto 7
# 86: pasajero con id 47 llego a su destino: colonia C, punto 8
# 87: pasajero con id 41 llego a su destino: colonia B, punto 6
# 87: vehiculo con id 4 volvio al punto de taxi. Tiempo del viaje: 8
# 87: pasajero con id 35 llego a su destino: colonia C, punto 9
# 87: pasajero con id 45 llego a su destino: colonia B, punto 6
# 87: pasajero con id 40 llego a su destino: colonia C, punto 9
# 88: pasajero con id 50 llego a su destino: colonia B, punto 3
# 89: pasajero con id 56 llego al punto con destino: colonia A, punto 10
# 89: pasajero con id 43 llego a su destino: colonia C, punto 10
# 89: vehiculo con id 1 volviendo al punto de taxi...
# 91: pasajero con id 46 llego a su destino: colonia B, punto 8
# 91: vehiculo con id 0 volviendo al punto de taxi...
# 93: pasajero con id 57 llego al punto con destino: colonia C, punto 10
# 97: pasajero con id 58 llego al punto con destino: colonia C, punto 4
# 97: pasajero con id 59 llego al punto con destino: colonia B, punto 9
# 99: pasajero con id 60 llego al punto con destino: colonia A, punto 6
# 99: pasajeros [54, 60, 51, 56] con destino a colonia A listos para subir a taxi
# 99: pasajeros [54, 60, 51, 56] subieron a vehiculo con id 3
# 101: pasajero con id 54 llego a su destino: colonia A, punto 3
# 103: pasajero con id 48 llego a su destino: colonia B, punto 10
# 103: vehiculo con id 1 volvio al punto de taxi. Tiempo del viaje: 28
# 103: pasajero con id 60 llego a su destino: colonia A, punto 6
# 103: pasajero con id 52 llego a su destino: colonia B, punto 10
# 103: pasajero con id 53 llego a su destino: colonia B, punto 10
# 103: vehiculo con id 2 volviendo al punto de taxi...
# 104: pasajero con id 61 llego al punto con destino: colonia B, punto 3
# 106: pasajero con id 51 llego a su destino: colonia A, punto 9
# 107: vehiculo con id 0 volvio al punto de taxi. Tiempo del viaje: 32
# 107: pasajero con id 56 llego a su destino: colonia A, punto 10
# 107: vehiculo con id 3 volviendo al punto de taxi...
# 108: pasajero con id 62 llego al punto con destino: colonia B, punto 5
# 108: pasajero con id 63 llego al punto con destino: colonia C, punto 7
# 108: pasajeros [58, 55, 63, 57] con destino a colonia C listos para subir a taxi
# 108: pasajero con id 64 llego al punto con destino: colonia A, punto 9
# 108: pasajeros [58, 55, 63, 57] subieron a vehiculo con id 4
# 110: pasajero con id 65 llego al punto con destino: colonia A, punto 4
# 110: pasajero con id 66 llego al punto con destino: colonia B, punto 8
# 110: pasajeros [61, 62, 66, 59] con destino a colonia B listos para subir a taxi
# 110: pasajeros [61, 62, 66, 59] subieron a vehiculo con id 1
# 111: pasajero con id 67 llego al punto con destino: colonia C, punto 8
# 111: pasajero con id 68 llego al punto con destino: colonia C, punto 8
# 111: pasajero con id 69 llego al punto con destino: colonia A, punto 2
# 112: pasajero con id 58 llego a su destino: colonia C, punto 4
# 115: vehiculo con id 3 volvio al punto de taxi. Tiempo del viaje: 16
# 115: pasajero con id 61 llego a su destino: colonia B, punto 3
# 115: pasajero con id 70 llego al punto con destino: colonia A, punto 9
# 115: pasajeros [69, 65, 64, 70] con destino a colonia A listos para subir a taxi
# 115: pasajeros [69, 65, 64, 70] subieron a vehiculo con id 0
# 116: pasajero con id 55 llego a su destino: colonia C, punto 7
# 116: pasajero con id 69 llego a su destino: colonia A, punto 2
# 116: pasajero con id 63 llego a su destino: colonia C, punto 7
# 117: pasajero con id 65 llego a su destino: colonia A, punto 4
# 118: pasajero con id 62 llego a su destino: colonia B, punto 5
# 119: pasajero con id 71 llego al punto con destino: colonia A, punto 9
# 119: pasajero con id 72 llego al punto con destino: colonia B, punto 9
# 119: pasajero con id 57 llego a su destino: colonia C, punto 10
# 119: vehiculo con id 4 volviendo al punto de taxi...
# 119: pasajero con id 64 llego a su destino: colonia A, punto 9
# 119: pasajero con id 70 llego a su destino: colonia A, punto 9
# 119: vehiculo con id 0 volviendo al punto de taxi...
# 123: vehiculo con id 2 volvio al punto de taxi. Tiempo del viaje: 40
# 123: pasajero con id 66 llego a su destino: colonia B, punto 8
# 123: pasajero con id 73 llego al punto con destino: colonia A, punto 10
# 123: pasajero con id 74 llego al punto con destino: colonia A, punto 8
# 123: vehiculo con id 0 volvio al punto de taxi. Tiempo del viaje: 8
# 124: pasajero con id 75 llego al punto con destino: colonia A, punto 2
# 124: pasajeros [75, 74, 71, 73] con destino a colonia A listos para subir a taxi
# 124: pasajero con id 76 llego al punto con destino: colonia C, punto 8
# 124: pasajero con id 77 llego al punto con destino: colonia B, punto 1
# 124: pasajeros [75, 74, 71, 73] subieron a vehiculo con id 3
# 125: pasajero con id 59 llego a su destino: colonia B, punto 9
# 125: vehiculo con id 1 volviendo al punto de taxi...
# 125: pasajero con id 78 llego al punto con destino: colonia C, punto 10
# 125: pasajeros [67, 68, 76, 78] con destino a colonia C listos para subir a taxi
# 125: pasajero con id 75 llego a su destino: colonia A, punto 2
# 125: pasajeros [67, 68, 76, 78] subieron a vehiculo con id 2
# 128: pasajero con id 74 llego a su destino: colonia A, punto 8
# 128: pasajero con id 71 llego a su destino: colonia A, punto 9
# 129: pasajero con id 79 llego al punto con destino: colonia A, punto 7
# 129: pasajero con id 80 llego al punto con destino: colonia A, punto 10
# 129: pasajero con id 73 llego a su destino: colonia A, punto 10
# 129: vehiculo con id 3 volviendo al punto de taxi...
# 130: vehiculo con id 4 volvio al punto de taxi. Tiempo del viaje: 22
# 132: pasajero con id 67 llego a su destino: colonia C, punto 8
# 132: pasajero con id 81 llego al punto con destino: colonia C, punto 2
# 132: pasajero con id 82 llego al punto con destino: colonia B, punto 8
# 132: pasajero con id 83 llego al punto con destino: colonia C, punto 5
# 132: pasajero con id 68 llego a su destino: colonia C, punto 8
# 132: pasajero con id 76 llego a su destino: colonia C, punto 8
# 133: pasajero con id 84 llego al punto con destino: colonia C, punto 1
# 134: vehiculo con id 3 volvio al punto de taxi. Tiempo del viaje: 10
# 134: pasajero con id 78 llego a su destino: colonia C, punto 10
# 134: vehiculo con id 2 volviendo al punto de taxi...
# 138: pasajero con id 85 llego al punto con destino: colonia C, punto 2
# 138: pasajeros [84, 81, 85, 83] con destino a colonia C listos para subir a taxi
# 138: pasajeros [84, 81, 85, 83] subieron a vehiculo con id 0
# 139: pasajero con id 84 llego a su destino: colonia C, punto 1
# 140: vehiculo con id 1 volvio al punto de taxi. Tiempo del viaje: 30
# 140: pasajero con id 81 llego a su destino: colonia C, punto 2
# 140: pasajero con id 85 llego a su destino: colonia C, punto 2
# 141: pasajero con id 86 llego al punto con destino: colonia C, punto 9
# 141: pasajero con id 87 llego al punto con destino: colonia C, punto 6
# 141: pasajero con id 88 llego al punto con destino: colonia A, punto 1
# 143: vehiculo con id 2 volvio al punto de taxi. Tiempo del viaje: 18
# 143: pasajero con id 83 llego a su destino: colonia C, punto 5
# 143: vehiculo con id 0 volviendo al punto de taxi...
# 145: pasajero con id 89 llego al punto con destino: colonia B, punto 3
# 145: pasajeros [77, 89, 82, 72] con destino a colonia B listos para subir a taxi
# 145: pasajero con id 90 llego al punto con destino: colonia B, punto 3
# 145: pasajero con id 91 llego al punto con destino: colonia C, punto 8
# 145: pasajeros [77, 89, 82, 72] subieron a vehiculo con id 4
# 146: pasajero con id 77 llego a su destino: colonia B, punto 1
# 148: vehiculo con id 0 volvio al punto de taxi. Tiempo del viaje: 10
# 149: pasajero con id 92 llego al punto con destino: colonia C, punto 8
# 149: pasajeros [87, 91, 92, 86] con destino a colonia C listos para subir a taxi
# 149: pasajero con id 93 llego al punto con destino: colonia A, punto 1
# 149: pasajeros [88, 93, 79, 80] con destino a colonia A listos para subir a taxi
# 149: pasajero con id 94 llego al punto con destino: colonia B, punto 10
# 149: pasajero con id 89 llego a su destino: colonia B, punto 3
# 149: pasajeros [87, 91, 92, 86] subieron a vehiculo con id 3
# 149: pasajeros [88, 93, 79, 80] subieron a vehiculo con id 1
# 149: pasajero con id 88 llego a su destino: colonia A, punto 1
# 149: pasajero con id 93 llego a su destino: colonia A, punto 1
# 152: pasajero con id 95 llego al punto con destino: colonia A, punto 5
# 152: pasajero con id 96 llego al punto con destino: colonia C, punto 4
# 153: pasajero con id 79 llego a su destino: colonia A, punto 7
# 154: pasajero con id 87 llego a su destino: colonia C, punto 6
# 155: pasajero con id 97 llego al punto con destino: colonia B, punto 3
# 156: pasajero con id 80 llego a su destino: colonia A, punto 10
# 156: vehiculo con id 1 volviendo al punto de taxi...
# 156: pasajero con id 91 llego a su destino: colonia C, punto 8
# 156: pasajero con id 92 llego a su destino: colonia C, punto 8
# 157: pasajero con id 86 llego a su destino: colonia C, punto 9
# 157: vehiculo con id 3 volviendo al punto de taxi...
# 158: pasajero con id 82 llego a su destino: colonia B, punto 8
# 159: pasajero con id 98 llego al punto con destino: colonia B, punto 2
# 159: pasajeros [98, 90, 97, 94] con destino a colonia B listos para subir a taxi
# 159: pasajero con id 99 llego al punto con destino: colonia C, punto 1
# 159: pasajero con id 72 llego a su destino: colonia B, punto 9
# 159: vehiculo con id 4 volviendo al punto de taxi...
# 159: pasajeros [98, 90, 97, 94] subieron a vehiculo con id 2
# 162: pasajero con id 98 llego a su destino: colonia B, punto 2
# 163: vehiculo con id 1 volvio al punto de taxi. Tiempo del viaje: 14
# 164: pasajero con id 100 llego al punto con destino: colonia B, punto 5
# 164: pasajero con id 101 llego al punto con destino: colonia C, punto 3
# 164: pasajeros [99, 101, 96, 102] con destino a colonia C listos para subir a taxi
# 164: pasajero con id 102 llego al punto con destino: colonia C, punto 6
# 164: pasajero con id 90 llego a su destino: colonia B, punto 3
# 164: pasajeros [99, 101, 96, 102] subieron a vehiculo con id 0
# 164: pasajero con id 97 llego a su destino: colonia B, punto 3
# 165: vehiculo con id 3 volvio al punto de taxi. Tiempo del viaje: 16
# 165: pasajero con id 99 llego a su destino: colonia C, punto 1
# 166: pasajero con id 103 llego al punto con destino: colonia B, punto 1
# 166: pasajero con id 104 llego al punto con destino: colonia C, punto 2
# 166: pasajero con id 105 llego al punto con destino: colonia A, punto 9
# 167: pasajero con id 101 llego a su destino: colonia C, punto 3
# 168: pasajero con id 96 llego a su destino: colonia C, punto 4
# 170: pasajero con id 102 llego a su destino: colonia C, punto 6
# 170: vehiculo con id 0 volviendo al punto de taxi...
# 171: pasajero con id 106 llego al punto con destino: colonia A, punto 5
# 173: vehiculo con id 4 volvio al punto de taxi. Tiempo del viaje: 28
# 173: pasajero con id 107 llego al punto con destino: colonia B, punto 2
# 176: vehiculo con id 0 volvio al punto de taxi. Tiempo del viaje: 12
# 177: pasajero con id 94 llego a su destino: colonia B, punto 10
# 177: vehiculo con id 2 volviendo al punto de taxi...
# 178: pasajero con id 108 llego al punto con destino: colonia A, punto 1
# 178: pasajeros [108, 95, 106, 105] con destino a colonia A listos para subir a taxi
# 178: pasajero con id 109 llego al punto con destino: colonia A, punto 2
# 178: pasajeros [108, 95, 106, 105] subieron a vehiculo con id 1
# 178: pasajero con id 108 llego a su destino: colonia A, punto 1

# %% [markdown]
# ## Definir dataframe de pasajeros

# %%
lista_pasajeros = []
for p in simulacion.pasajeros:
    lista_pasajeros.append({
        "pasajero": p.id
        , "colonia": p.destino.colonia.nombre
        , "punto": p.destino.punto
        , "vehiculo": p.vehiculo
        , "distancia": p.destino.distancia_absoluta
    })

df_pasajeros = pd.DataFrame(lista_pasajeros)

# %%
df_pasajeros
# Out:
#      pasajero colonia  punto  vehiculo  distancia
# 0           1       B      4       0.0        2.4
# 1           2       B      2       0.0        1.2
# 2           3       C      6       4.0        2.4
# 3           4       B      5       0.0        3.0
# 4           5       A      6       3.0        1.2
# ..        ...     ...    ...       ...        ...
# 104       105       A      9       1.0        1.8
# 105       106       A      5       1.0        1.0
# 106       107       B      2       NaN        1.2
# 107       108       A      1       1.0        0.2
# 108       109       A      2       NaN        0.4
#
# [109 rows x 5 columns]

# %% [markdown]
# ## Definir dataframe de eventos de pasajeros

# %%
lista_eventos_pasajeros = []
for p in simulacion.pasajeros:
    lista_eventos_pasajeros.append(p.eventos)

# %%
df_eventos_pasajeros = pd.concat(lista_eventos_pasajeros)
df_eventos_pasajeros = df_eventos_pasajeros.reset_index()
df_eventos_pasajeros.drop(["index"], axis = 1, inplace = True)

# %%
df_eventos_pasajeros
# Out:
#      pasajero              evento  tiempo
# 0           1      LLEGO AL PUNTO       5
# 1           1    SUBIO A VEHICULO      13
# 2           1  LLEGO A SU DESTINO      22
# 3           2      LLEGO AL PUNTO       5
# 4           2    SUBIO A VEHICULO      13
# ..        ...                 ...     ...
# 309       107      LLEGO AL PUNTO     173
# 310       108      LLEGO AL PUNTO     178
# 311       108    SUBIO A VEHICULO     178
# 312       108  LLEGO A SU DESTINO     178
# 313       109      LLEGO AL PUNTO     178
#
# [314 rows x 3 columns]

# %% [markdown]
# ## Definir dataframe de eventos de vehiculos

# %%
lista_eventos_vehiculos = []
for v in simulacion.vehiculos:
    lista_eventos_vehiculos.append(v.eventos)

# %%
df_eventos_vehiculos = pd.concat(lista_eventos_vehiculos)
df_eventos_vehiculos = df_eventos_vehiculos.reset_index()
df_eventos_vehiculos.drop(["index"], axis = 1, inplace = True)

# %%
df_eventos_vehiculos
# Out:
#     vehiculo            evento  tiempo
# 0          0    LLEGO AL PUNTO       0
# 1          0  HACIA EL DESTINO      13
# 2          0    HACIA EL PUNTO      25
# 3          0    LLEGO AL PUNTO      37
# 4          0  HACIA EL DESTINO      48
# ..       ...               ...     ...
# 75         4    HACIA EL PUNTO     119
# 76         4    LLEGO AL PUNTO     130
# 77         4  HACIA EL DESTINO     145
# 78         4    HACIA EL PUNTO     159
# 79         4    LLEGO AL PUNTO     173
#
# [80 rows x 3 columns]

# %% [markdown]
# ## Preguntas a responder
# - En promedio, cuanto esperaron los pasajeros en poder subirse a un vehiculo?
# - Cual fue la colonia destino mas frecuente?
# - En promedio, cuanto duraron los viajes de los vehiculos?
# - Que vehiculo realizo la mayor cantidad de viajes?
# - En promedio, que vehiculo realizo los viajes mas largos?

# %% [markdown]
# ### 1. En promedio, cuanto esperaron los pasajeros en poder subirse a un vehiculo?

# %%
df_eventos_pasajeros["lag_tiempo"] = df_eventos_pasajeros.groupby("pasajero")["tiempo"].shift(1)
df1 = df_eventos_pasajeros.loc[ df_eventos_pasajeros["evento"] == "SUBIO A VEHICULO", : ].copy()
df1["tiempo_espera"] = df1["tiempo"] - df1["lag_tiempo"]

# %%
df1.merge(
    df_pasajeros
    , on = ["pasajero"]
    , how = "inner"
).groupby(
    "evento"
).agg({
    "tiempo_espera": ["mean"]
})
# Out:
#                  tiempo_espera
#                           mean
# evento
# SUBIO A VEHICULO      7.288462

# %% [markdown]
# ### 2. Cual fue la colonia destino mas frecuente?

# %%
df2 = df_pasajeros.groupby(["colonia"], as_index = False).agg({
    "pasajero": ["count"]
})

df2.columns = [ "colonia", "pasajeros" ]

# %%
df2.sort_values("pasajeros", ascending = False)
# Out:
#   colonia  pasajeros
# 1       B         43
# 0       A         37
# 2       C         29

# %% [markdown]
# ### 3. En promedio, cuanto duraron los viajes de los vehiculos?

# %%
df_eventos_vehiculos["lag_tiempo"] = df_eventos_vehiculos.groupby("vehiculo")["tiempo"].shift(3)
df3 = df_eventos_vehiculos.loc[ df_eventos_vehiculos["evento"] == "LLEGO AL PUNTO", : ].copy()
df3["tiempo_viaje"] = df3["tiempo"] - df3["lag_tiempo"]

# %%
df3.groupby(
    "evento"
).agg({
    "tiempo_viaje": ["mean"]
})
# Out:
#                tiempo_viaje
#                        mean
# evento
# LLEGO AL PUNTO    34.166667

# %% [markdown]
# ### 4. Que vehiculo realizo la mayor cantidad de viajes?

# %%
df4 = df_eventos_vehiculos.loc[ df_eventos_vehiculos["evento"] == "LLEGO AL PUNTO", : ]
df4 = df4.groupby("vehiculo").agg({ "vehiculo": ["count"] })
df4.columns = [ "viajes" ]

# %%
df4.sort_values("viajes", ascending = False)
# Out:
#           viajes
# vehiculo
# 0              7
# 4              6
# 3              6
# 2              5
# 1              5

# %% [markdown]
# ### 5. En promedio, que vehiculo realizo los viajes mas largos?

# %%
df5 = df_pasajeros.merge(
    df_eventos_vehiculos
    , on = ["vehiculo"]
    , how = "left"
).loc[ : , ["pasajero", "vehiculo", "distancia"] ].groupby("vehiculo").agg({
    "distancia": ["mean"]
})

df5.columns = [ "distancia" ]

# %%
df5.sort_values("distancia", ascending = False)
# Out:
#           distancia
# vehiculo
# 2.0        3.080000
# 1.0        2.550000
# 3.0        2.100000
# 4.0        1.850000
# 0.0        1.691667
